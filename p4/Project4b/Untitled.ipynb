# %%
import pandas as pd
import matplotlib
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-42-cdaf6904e809> in <module>()
#       1 import pandas as pd
# ----> 2 import matplotlib
#
# ImportError: No module named 'matplotlib'

# %%
df_car = pd.read_csv('q6_result_car.txt')

# %%
df_car.columns = ['Num Hidden Layer', 'Max Car', 'Average Car', 'STD Car']

# %%
df_car
# Out:
#   Num Hidden Layer   Max Car  Average Car   STD Car
# 0              [0]  0.692408     0.692408  0.000000
# 1              [5]  0.844241     0.826440  0.011877
# 2             [10]  0.826571     0.816885  0.005726
# 3             [15]  0.835733     0.820681  0.013444
# 4             [20]  0.830497     0.821073  0.005294
# 5             [25]  0.825262     0.815445  0.006725
# 6             [30]  0.823298     0.811649  0.010384
# 7             [35]  0.827225     0.818586  0.005258
# 8             [40]  0.818717     0.809817  0.006983

# %%
df_pen = pd.read_csv('q6_result_pen.txt')

# %%
df_pen
# Out:
#   Hidden Layer       Max      Mean       STD
# 0          [0]  0.000000  0.000000  0.000000
# 1          [5]  0.857347  0.840023  0.009853
# 2         [10]  0.897370  0.890509  0.004971
# 3         [15]  0.901944  0.892739  0.006500
# 4         [20]  0.908805  0.905889  0.002180
# 5         [25]  0.909091  0.903030  0.003764
# 6         [30]  0.905946  0.902630  0.002298
# 7         [35]  0.909377  0.903145  0.007149
# 8         [40]  0.905374  0.901544  0.003462

# %%
df_pen.columns = ['Num Hidden Layer', 'Max Pen', 'Average Pen', 'STD Pen']

# %%
df_pen
# Out:
#   Num Hidden Layer   Max Pen  Average Pen   STD Pen
# 0              [0]  0.000000     0.000000  0.000000
# 1              [5]  0.857347     0.840023  0.009853
# 2             [10]  0.897370     0.890509  0.004971
# 3             [15]  0.901944     0.892739  0.006500
# 4             [20]  0.908805     0.905889  0.002180
# 5             [25]  0.909091     0.903030  0.003764
# 6             [30]  0.905946     0.902630  0.002298
# 7             [35]  0.909377     0.903145  0.007149
# 8             [40]  0.905374     0.901544  0.003462

# %%
df_pen['Max Car'] = df_car['Max Car']

# %%
df_pen
# Out:
#   Num Hidden Layer   Max Pen  Average Pen   STD Pen   Max Car
# 0              [0]  0.000000     0.000000  0.000000  0.692408
# 1              [5]  0.857347     0.840023  0.009853  0.844241
# 2             [10]  0.897370     0.890509  0.004971  0.826571
# 3             [15]  0.901944     0.892739  0.006500  0.835733
# 4             [20]  0.908805     0.905889  0.002180  0.830497
# 5             [25]  0.909091     0.903030  0.003764  0.825262
# 6             [30]  0.905946     0.902630  0.002298  0.823298
# 7             [35]  0.909377     0.903145  0.007149  0.827225
# 8             [40]  0.905374     0.901544  0.003462  0.818717

# %%
df_pen['Average Car'] = df_car['Average Car']

# %%
df_pen['STD Car'] = df_car['STD Car']

# %%
df_pen
# Out:
#   Num Hidden Layer   Max Pen  Average Pen   STD Pen   Max Car  Average Car  \
# 0              [0]  0.000000     0.000000  0.000000  0.692408     0.692408
# 1              [5]  0.857347     0.840023  0.009853  0.844241     0.826440
# 2             [10]  0.897370     0.890509  0.004971  0.826571     0.816885
# 3             [15]  0.901944     0.892739  0.006500  0.835733     0.820681
# 4             [20]  0.908805     0.905889  0.002180  0.830497     0.821073
# 5             [25]  0.909091     0.903030  0.003764  0.825262     0.815445
# 6             [30]  0.905946     0.902630  0.002298  0.823298     0.811649
# 7             [35]  0.909377     0.903145  0.007149  0.827225     0.818586
# 8             [40]  0.905374     0.901544  0.003462  0.818717     0.809817
#
#     STD Car
# 0  0.000000
# 1  0.011877
# 2  0.005726
# 3  0.013444
# 4  0.005294
# 5  0.006725
# 6  0.010384
# 7  0.005258
# 8  0.006983

# %%
df_merged = df_pen[['Num Hidden Layer', 'Max Pen', 'Max Car', 'Average Pen', 'Average Car', 'STD Pen', 'STD Car']]

# %%
df_merged
# Out:
#   Num Hidden Layer   Max Pen   Max Car  Average Pen  Average Car   STD Pen  \
# 0              [0]  0.000000  0.692408     0.000000     0.692408  0.000000
# 1              [5]  0.857347  0.844241     0.840023     0.826440  0.009853
# 2             [10]  0.897370  0.826571     0.890509     0.816885  0.004971
# 3             [15]  0.901944  0.835733     0.892739     0.820681  0.006500
# 4             [20]  0.908805  0.830497     0.905889     0.821073  0.002180
# 5             [25]  0.909091  0.825262     0.903030     0.815445  0.003764
# 6             [30]  0.905946  0.823298     0.902630     0.811649  0.002298
# 7             [35]  0.909377  0.827225     0.903145     0.818586  0.007149
# 8             [40]  0.905374  0.818717     0.901544     0.809817  0.003462
#
#     STD Car
# 0  0.000000
# 1  0.011877
# 2  0.005726
# 3  0.013444
# 4  0.005294
# 5  0.006725
# 6  0.010384
# 7  0.005258
# 8  0.006983

# %%
df_merged.set_index('Num Hidden Layer')
# Out:
#                    Max Pen   Max Car  Average Pen  Average Car   STD Pen  \
# Num Hidden Layer
# [0]               0.000000  0.692408     0.000000     0.692408  0.000000
# [5]               0.857347  0.844241     0.840023     0.826440  0.009853
# [10]              0.897370  0.826571     0.890509     0.816885  0.004971
# [15]              0.901944  0.835733     0.892739     0.820681  0.006500
# [20]              0.908805  0.830497     0.905889     0.821073  0.002180
# [25]              0.909091  0.825262     0.903030     0.815445  0.003764
# [30]              0.905946  0.823298     0.902630     0.811649  0.002298
# [35]              0.909377  0.827225     0.903145     0.818586  0.007149
# [40]              0.905374  0.818717     0.901544     0.809817  0.003462
#
#                    STD Car
# Num Hidden Layer
# [0]               0.000000
# [5]               0.011877
# [10]              0.005726
# [15]              0.013444
# [20]              0.005294
# [25]              0.006725
# [30]              0.010384
# [35]              0.005258
# [40]              0.006983

# %%
df_merged.plot()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-38-c7e9fd47035d> in <module>()
# ----> 1 df_merged.plot()
#
# C:\Users\BudiRyan\Anaconda2\envs\py35\lib\site-packages\pandas\tools\plotting.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3771                           fontsize=fontsize, colormap=colormap, table=table,
#    3772                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3773                           sort_columns=sort_columns, **kwds)
#    3774     __call__.__doc__ = plot_frame.__doc__
#    3775
#
# C:\Users\BudiRyan\Anaconda2\envs\py35\lib\site-packages\pandas\tools\plotting.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2640                  yerr=yerr, xerr=xerr,
#    2641                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 2642                  **kwds)
#    2643
#    2644
#
# C:\Users\BudiRyan\Anaconda2\envs\py35\lib\site-packages\pandas\tools\plotting.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2465                             pass
#    2466                 data = series
# -> 2467         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    2468
#    2469     plot_obj.generate()
#
# C:\Users\BudiRyan\Anaconda2\envs\py35\lib\site-packages\pandas\tools\plotting.py in __init__(self, data, **kwargs)
#    1678
#    1679     def __init__(self, data, **kwargs):
# -> 1680         MPLPlot.__init__(self, data, **kwargs)
#    1681         if self.stacked:
#    1682             self.data = self.data.fillna(value=0)
#
# C:\Users\BudiRyan\Anaconda2\envs\py35\lib\site-packages\pandas\tools\plotting.py in __init__(self, data, kind, by, subplots, sharex, sharey, use_index, figsize, grid, legend, rot, ax, fig, title, xlim, ylim, xticks, yticks, sort_columns, fontsize, secondary_y, colormap, table, layout, **kwds)
#     938
#     939         if grid is None:
# --> 940             grid = False if secondary_y else self.plt.rcParams['axes.grid']
#     941
#     942         self.grid = grid
#
# pandas\src\properties.pyx in pandas.lib.cache_readonly.__get__ (pandas\lib.c:43685)()
#
# C:\Users\BudiRyan\Anaconda2\envs\py35\lib\site-packages\pandas\tools\plotting.py in plt(self)
#    1295     @cache_readonly
#    1296     def plt(self):
# -> 1297         import matplotlib.pyplot as plt
#    1298         return plt
#    1299
#
# ImportError: No module named 'matplotlib'
